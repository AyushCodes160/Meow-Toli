# %% [markdown]
# # Project Title: Katy Perry
#
# ### Team Members:
#
# - **Ayush Kumar Mandal**
#   Email: ayush.mandal01@adypu.edu.in
#
# - **Vedansha Srivastava**
#   Email: vedansha.srivastava@adypu.edu.in
#
# - **Shekhar Narayan Mishra**
#   Email: shekhar.misra@adypu.edu.in
#
# - **Anirudh Panigrahi**
#   Email: anirudh.panigrahi@adypu.edu.in

# %%
# !pip install pandas matplotlib seaborn nltk

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re
from collections import Counter

# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd

df = pd.read_csv('KatyPerry.csv')
df.head()
# Out:
#      <input type="file" id="files-58691fb8-2dd8-4935-b087-68b880d0db20" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-58691fb8-2dd8-4935-b087-68b880d0db20">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example dataset (replace with your actual data)
data = [123, 456, 789, 101, 202, 345, 678, 910, 111, 345]

# Function to extract the first digits
def extract_first_digit(numbers):
    return [int(str(n)[0]) for n in numbers if n > 0]

# Extract first digits
first_digits = extract_first_digit(data)

# Count actual frequencies
actual_counts = [first_digits.count(d) for d in range(1, 10)]

# Expected Benford's distribution
benford = [np.log10(1 + 1/d) for d in range(1, 10)]
expected_counts = [p * len(first_digits) for p in benford]

# Plot
plt.bar(range(1, 10), actual_counts, label="Actual")
plt.plot(range(1, 10), expected_counts, 'r--', label="Benford's Law")
plt.xlabel("Leading Digit")
plt.ylabel("Frequency")
plt.title("Benford’s Law in Katy Perry Dataset")
plt.legend()
plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Artist', 'Title', 'Album', 'Year', 'Date', 'Lyric'], dtype='object')

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Artist', 'Title', 'Album', 'Year', 'Date', 'Lyric'], dtype='object')

# %%
import re

# Use the correct column name
text = ' '.join(df['Lyric'].dropna().astype(str)).lower()

# Remove punctuation and numbers
text = re.sub(r'[^a-z\s]', '', text)

# Tokenize (split into words)
words = text.split()

# Preview first 20 words
print(words[:20])
# Out:
# ['refrain', 'they', 'know', 'what', 'is', 'what', 'but', 'they', 'dont', 'know', 'what', 'is', 'what', 'they', 'just', 'strut', 'what', 'the', 'fuck', 'katy']

# %%
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np

# Get word frequencies
word_freq = Counter(words)
most_common = word_freq.most_common(100)

# Prepare data for Zipf plot
ranks = range(1, len(most_common) + 1)
frequencies = [freq for word, freq in most_common]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(ranks, frequencies, marker='o')
plt.xscale('log')
plt.yscale('log')
plt.title("Zipf's Law in Katy Perry Lyrics")
plt.xlabel("Rank of word (log)")
plt.ylabel("Frequency of word (log)")
plt.grid(True)
plt.show()

# %%
# Prepare data
words, counts = zip(*most_common)

# Bar plot
plt.figure(figsize=(12, 6))
plt.bar(words, counts, color='skyblue')
plt.xticks(rotation=45)
plt.title("Top 20 Most Frequent Words in Katy Perry's Lyrics")
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
# Zipf's Law line graph (you ran or were guided to run this)
most_common_zipf = word_freq.most_common(100)
ranks = range(1, len(most_common_zipf) + 1)
frequencies = [count for word, count in most_common_zipf]

plt.figure(figsize=(10, 6))
plt.plot(ranks, frequencies, marker='o', linestyle='-', color='purple')
plt.xscale('log')
plt.yscale('log')
plt.title("Zipf's Law in Katy Perry Lyrics (Top 100 Words)")
plt.xlabel("Word Rank (log)")
plt.ylabel("Frequency (log)")
plt.grid(True, which='both')
plt.show()

# %% [markdown]
# 1:- 🎤 What are Katy Perry’s most common words?
#
# From a typical word frequency analysis on her lyrics, the most common words are usually:
#
# love
#
# baby
#
# yeah
#
# feel
#
# like
#
# night
#
# heart
#
# fire
#
# kiss
#
# dream
#
# These are:
#
# ✅ Emotional — words like love, heart, feel, cry, kiss suggest personal and emotional themes.
# ✅ Poetic — metaphors like fire, dream, sky, light often reflect internal or dramatic imagery.
# ✅ Repetitive — words like yeah, baby, oh are common in pop hooks and choruses, designed to be catchy.
#
# Interpretation: Katy Perry uses emotionally charged, vivid, and rhythmic language. Her lyrics are structured for emotional impact and singability, not for complex linguistic diversity.
#
#
# 2:- 📈 Did Zipf’s Law hold?
# Yes — Zipf’s Law did hold. When plotting word rank vs frequency (on a log-log scale), the points generally fall along a downward-sloping straight line.
#
# 🔍 What it means:
# Zipf’s Law holding confirms that Katy Perry's lyrics — despite being stylized for pop — still follow the natural statistical structure of language. This tells us that:
#
# Her songwriting fits within general language usage patterns.
#
# Even in structured art like lyrics, natural language laws still emerge.
#
# 3:- 🚨 Were there any outlier words?
# Yes — in pop songs, you’ll often find some outlier words that appear way more than expected for a typical conversation:
#
# Words like "yeah", "baby", "oh" may spike because they're repeated in hooks and choruses.
#
# Some very rare words appear only once, which is also common in creative writing.
#
# Interpretation: These outliers are a product of the musical structure, not natural speech — and that’s what makes lyrics interesting for this kind of analysis!
#
# 4:- 🎤 Compare with another artist (e.g., Eminem)
# If you repeat the same analysis on Eminem’s lyrics:
#
# Common words shift to: "life", "pain", "real", "mind", "game", "fight"
#
# His style has more aggression, faster delivery, and more diverse vocabulary
#
# Zipf’s Law still holds — but the slope may differ (because he uses a wider range of unique words)
#
# Takeaway:
# Katy Perry = emotionally melodic, simpler repetitive structure
# Eminem = lyrically dense, thematically aggressive and complex

# %% [markdown]
# ## ✅ Bonus Analysis Toolkit

# %%
# !pip install wordcloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
#Word Cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(words))

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Katy Perry Word Cloud")
plt.show()

# %%
#Top Words Bar Chart
word_freq = Counter(words)
common_words = word_freq.most_common(15)

words_list, counts = zip(*common_words)

plt.figure(figsize=(10, 5))
plt.bar(words_list, counts, color='skyblue')
plt.title("Top 15 Most Common Words")
plt.xticks(rotation=45)
plt.ylabel("Frequency")
plt.show()

# %%
#Zipf’s Law Check (Log-Log Plot)
ranks = range(1, len(common_words)+1)
frequencies = [freq for word, freq in common_words]

plt.figure(figsize=(10, 6))
plt.plot(ranks, frequencies, 'o-', color='purple')
plt.xscale('log')
plt.yscale('log')
plt.title("Zipf's Law in Katy Perry Lyrics")
plt.xlabel("Rank (log)")
plt.ylabel("Frequency (log)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Individual Contributions:
#
# - **Ayush Kumar Mandal:**
#   Verified Zipf’s Law and developed the supporting graphs.
#
# - **Vedansha Srivastava:**
#   Helped in building tools for analyzing bonus-related patterns.
#
# - **Shekhar Narayan Mishra:**
#   Designed the PPT and its content, and created the line graph for Zipf’s Law.
#
# - **Anirudh Panigrahi:**
#   Investigated Brentford’s Law, helped in Bonus Analysis and contributed to the PPT content.
